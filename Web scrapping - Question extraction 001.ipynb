# %%
import requests
import csv
from bs4 import BeautifulSoup as bs

# %%
url = 'https://www.indiabix.com/logical-reasoning/number-series/'

# %%
page = requests.get(url)

# %%
soup = bs(page.content, 'html.parser')
soup
# Out:
# <!--<!DOCTYPE html>-->
# <html lang="en">
# <head>
# <!--<meta charset="utf-8" content="utf-8">-->
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#2299c5" name="theme-color"/>
# <title>Number Series - Logical Reasoning Questions and Answers</title>
# <meta content="number, series, type, 1, logical, reasoning, questions, answers, explanation, solutions, examples, interview, entrance, exam, online, test, quiz, pdf, download, freshers, ebooks" name="keywords">
# <meta content='This is the logical reasoning questions and answers section on "Number Series" with explanation for various interview, competitive examination and entrance test. Solved examples with detailed answer description, explanation are given and it would be easy to understand.' name="description">
# <link href="/_files/css/css-res-min-1-15.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="/_files/js/js-res-10.js" type="text/javascript"></script>
# ...

# %%
print(soup.prettify())
# Out:
# <!--<!DOCTYPE html>-->
# <html lang="en">
#  <head>
#   <!--<meta charset="utf-8" content="utf-8">-->
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#2299c5" name="theme-color"/>
#   <title>
#    Number Series - Logical Reasoning Questions and Answers
#   </title>
#   <meta content="number, series, type, 1, logical, reasoning, questions, answers, explanation, solutions, examples, interview, entrance, exam, online, test, quiz, pdf, download, freshers, ebooks" name="keywords">
#    <meta content='This is the logical reasoning questions and answers section on "Number Series" with explanation for various interview, competitive examination and entrance test. Solved examples with detailed answer description, explanation are given and it would be easy to understand.' name="description">
#     <link href="/_files/css/css-res-min-1-15.css" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
# Question - 1

qestion1 = soup.find('td', class_="bix-td-qtxt")
qestion1.text
# Out:
# 'Look at this series: 2, 1, (1/2), (1/4), ... What number should come next?'

# %%
# Q1 - Aa

ans1a = soup.find('td', id="tdOptionDt_A_20")
ans1a.text
# Out:
# '(1/3)'

# %%
# Q1 - Ab

ans1b = soup.find('td', id="tdOptionDt_B_20")
ans1b.text
# Out:
# '(1/8)'

# %%
# Q1 - Ac

ans1c = soup.find('td', id="tdOptionDt_C_20")
ans1c.text
# Out:
# '(2/8)'

# %%
# Q1 - Ad

ans1d = soup.find('td', id="tdOptionDt_D_20")
ans1d.text
# Out:
# '(1/16)'

# %%
# Q1 - A's

ans1 = [ans1a.text, ans1b.text, ans1c.text, ans1d.text]
ans1
# Out:
# ['(1/3)', '(1/8)', '(2/8)', '(1/16)']

# %%
# page1 - All answers
# it will inlcude of 1)answers  2)correct answer   3)explanation

ns_1_pg1_q_ans = []

for i in soup.findAll('td', class_="bix-td-miscell"):
    ns_1_pg1_q_ans.append(i.text)
    
ns_1_pg1_q_ans
# Out:
# ['A.\n(1/3)B.\n(1/8)C.\n(2/8)D.\n(1/16)\n\nAnswer: Option B\nExplanation:\n This is a simple division series; each number is one-half of the previous number.\nIn other terms to say, the number is divided by 2 successively to get the next result.\n\n4/2 = 2\n2/2 = 1\n1/2 = 1/2\n(1/2)/2 = 1/4\n(1/4)/2 = 1/8 and so on.\n \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n',
#  'A.\n7B.\n10C.\n12D.\n13\n\nAnswer: Option B\nExplanation:\n This is a simple alternating addition and subtraction series. In the first pattern, 3 is added; in the second, 2 is subtracted. \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n',
#  'A.\n20B.\n22C.\n23D.\n26\n\nAnswer: Option B\nExplanation:\n This is an alternating number subtraction series. First, 2 is subtracted, then 4, then 2, and so on. \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n',
# ...

# %%
ns_1_pg1_q1_ans = soup.find('td', class_="bix-td-miscell")
print(ns_1_pg1_q1_ans.text)
# Out:
# A.
# (1/3)B.
# (1/8)C.
# (2/8)D.
# (1/16)
#
# Answer: Option B
# Explanation:
#  This is a simple division series; each number is one-half of the previous number.
# In other terms to say, the number is divided by 2 successively to get the next result.
#
# 4/2 = 2
# 2/2 = 1
# 1/2 = 1/2
# (1/2)/2 = 1/4
# (1/4)/2 = 1/8 and so on.
#
#
#
# Workspace
#
#
#
# Report errors
# ...
#
#
#
#
# Name :
# Email:

# %%
# Q1 - A

ans_1 = soup.find(class_="jq-hdnakqb mx-bold")
ans_1.text
# Out:
# 'B'

# %%
# Q1 - AD

ans_1d = soup.find('div', class_="bix-ans-description")
ans_1d.text
# Out:
# ' This is a simple division series; each number is one-half of the previous number.\nIn other terms to say, the number is divided by 2 successively to get the next result.\n\n4/2 = 2\n2/2 = 1\n1/2 = 1/2\n(1/2)/2 = 1/4\n(1/4)/2 = 1/8 and so on.\n '

# %%
# page 1 questions

ns_1_pg1_qs = []

for i in soup.findAll('td', class_="bix-td-qtxt"):
    ns_1_pg1_qs.append(i.text)
    
ns_1_pg1_qs
# Out:
# ['Look at this series: 2, 1, (1/2), (1/4), ... What number should come next?',
#  'Look at this series: 7, 10, 8, 11, 9, 12, ... What number should come next?',
#  'Look at this series: 36, 34, 30, 28, 24, ... What number should come next?',
#  'Look at this series: 22, 21, 23, 22, 24, 23, ... What number should come next?',
#  'Look at this series: 53, 53, 40, 40, 27, 27, ... What number should come next?']

# %%
# page 1 Q - Aa

ns_1_pg1_Aa = []

for i in soup.find('td', class_="bix-td-miscell"):
    ns_1_pg1_Aa.append(i.text)
    
print(ns_1_pg1_Aa)
# Out:
# ['A.\n(1/3)B.\n(1/8)C.\n(2/8)D.\n(1/16)', '\n\nAnswer: Option B\nExplanation:\n This is a simple division series; each number is one-half of the previous number.\nIn other terms to say, the number is divided by 2 successively to get the next result.\n\n4/2 = 2\n2/2 = 1\n1/2 = 1/2\n(1/2)/2 = 1/4\n(1/4)/2 = 1/8 and so on.\n \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n']

# %%
print(ns_1_pg1_Aa[0])
len(ns_1_pg1_Aa)
# Out:
# A.
# (1/3)B.
# (1/8)C.
# (2/8)D.
# (1/16)
# 2

# %%
# page1 - All answers
# it will inlcude of 1)answers  2)correct answer   3)explanation

ns_1_pg1_q_ans = []

for i in soup.findAll('td', class_="bix-td-miscell"):
    ns_1_pg1_q_ans.append(i.text)
    
print(ns_1_pg1_q_ans)
# Out:
# ['A.\n(1/3)B.\n(1/8)C.\n(2/8)D.\n(1/16)\n\nAnswer: Option B\nExplanation:\n This is a simple division series; each number is one-half of the previous number.\nIn other terms to say, the number is divided by 2 successively to get the next result.\n\n4/2 = 2\n2/2 = 1\n1/2 = 1/2\n(1/2)/2 = 1/4\n(1/4)/2 = 1/8 and so on.\n \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n', 'A.\n7B.\n10C.\n12D.\n13\n\nAnswer: Option B\nExplanation:\n This is a simple alternating addition and subtraction series. In the first pattern, 3 is added; in the second, 2 is subtracted. \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n', 'A.\n20B.\n22C.\n23D.\n26\n\nAnswer: Option B\nExplanation:\n This is an alternating number subtraction series. First, 2 is subtracted, then 4, then 2, and so on. \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n', 'A.\n22B.\n24C.\n25D.\n26\n\nAnswer: Option C\nExplanation:\n In this simple alternating subtracti
# ...

# %%
# page1 - All answers
# it will inlcude of 1)answers  2)correct answer   3)explanation

ns_1_pg1_q_ans = []

for i in soup.findAll('td', class_="bix-td-miscell"):
    ns_1_pg1_q_ans.append(i.text)
    
print(ns_1_pg1_q_ans)
# Out:
# ['A.\n(1/3)B.\n(1/8)C.\n(2/8)D.\n(1/16)\n\nAnswer: Option B\nExplanation:\n This is a simple division series; each number is one-half of the previous number.\nIn other terms to say, the number is divided by 2 successively to get the next result.\n\n4/2 = 2\n2/2 = 1\n1/2 = 1/2\n(1/2)/2 = 1/4\n(1/4)/2 = 1/8 and so on.\n \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n', 'A.\n7B.\n10C.\n12D.\n13\n\nAnswer: Option B\nExplanation:\n This is a simple alternating addition and subtraction series. In the first pattern, 3 is added; in the second, 2 is subtracted. \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n', 'A.\n20B.\n22C.\n23D.\n26\n\nAnswer: Option B\nExplanation:\n This is an alternating number subtraction series. First, 2 is subtracted, then 4, then 2, and so on. \n\n\nWorkspace\n\n\n\nReport errors\n...\n\n\n\n\nName : \nEmail: \n\n\n', 'A.\n22B.\n24C.\n25D.\n26\n\nAnswer: Option C\nExplanation:\n In this simple alternating subtracti
# ...

# %%
dir(bs)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_check_markup_is_url',
#  '_decode_markup',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_popToTag',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14696/764529734.py in <module>
#       1 list = [1,[2,2,2],4]
# ----> 2 l = [item for sublist in list for item in sublist]
#       3 l
#
# ~\AppData\Local\Temp/ipykernel_14696/764529734.py in <listcomp>(.0)
#       1 list = [1,[2,2,2],4]
# ----> 2 l = [item for sublist in list for item in sublist]
#       3 l
#
# TypeError: 'int' object is not iterable
